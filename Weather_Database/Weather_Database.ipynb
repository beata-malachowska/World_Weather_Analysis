# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
len(cities)
# Out:
# 771

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,                          
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | mahebourg
# Processing Record 3 of Set 1 | isangel
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | hun
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | severo-kurilsk
# Processing Record 8 of Set 1 | hithadhoo
# Processing Record 9 of Set 1 | ligayan
# Processing Record 10 of Set 1 | gizo
# Processing Record 11 of Set 1 | paro
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | dwarka
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | porbandar
# Processing Record 16 of Set 1 | mortka
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | coihaique
# Processing Record 19 of Set 1 | margate
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 1 | saint george
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | iqaluit
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | esperance
# Processing Record 27 of Set 1 | muros
# Processing Record 28 of Set 1 | breznik
# Processing Record 29 of Set 1 | mount gambier
# Processing Record 30 of Set 1 | atakpame
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | felidhoo
# City not found. Skipping...
# Processing Record 33 of Set 1 | pangnirtung
# Processing Record 34 of Set 1 | tasiilaq
# Processing Record 35 of Set 1 | biak
# Processing Record 36 of Set 1 | salalah
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | comodoro rivadavia
# Processing Record 39 of Set 1 | saint-philippe
# Processing Record 40 of Set 1 | chake chake
# Processing Record 41 of Set 1 | san juan
# Processing Record 42 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | saskylakh
# Processing Record 45 of Set 1 | penzance
# Processing Record 46 of Set 1 | chokurdakh
# Processing Record 47 of Set 1 | atuona
# Processing Record 48 of Set 1 | bosaso
# Processing Record 49 of Set 1 | port lincoln
# Processing Record 50 of Set 1 | monrovia
# Processing Record 1 of Set 2 | khakhea
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | kissidougou
# Processing Record 4 of Set 2 | mar del plata
# Processing Record 5 of Set 2 | inuvik
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | tiksi
# Processing Record 8 of Set 2 | airai
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 2 | novyy urengoy
# Processing Record 12 of Set 2 | souillac
# Processing Record 13 of Set 2 | dikson
# Processing Record 14 of Set 2 | nijar
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | qaanaaq
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | talas
# Processing Record 19 of Set 2 | punta gorda
# Processing Record 20 of Set 2 | maceio
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | fortuna
# Processing Record 23 of Set 2 | clyde river
# Processing Record 24 of Set 2 | kodiak
# Processing Record 25 of Set 2 | lashio
# Processing Record 26 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 2 | pousat
# City not found. Skipping...
# Processing Record 28 of Set 2 | lasa
# Processing Record 29 of Set 2 | provost
# Processing Record 30 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 31 of Set 2 | roebourne
# Processing Record 32 of Set 2 | pevek
# Processing Record 33 of Set 2 | rasht
# Processing Record 34 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 2 | provideniya
# Processing Record 36 of Set 2 | bengkulu
# Processing Record 37 of Set 2 | damara
# Processing Record 38 of Set 2 | waverley
# Processing Record 39 of Set 2 | naze
# Processing Record 40 of Set 2 | upernavik
# Processing Record 41 of Set 2 | port augusta
# Processing Record 42 of Set 2 | porto novo
# Processing Record 43 of Set 2 | oksfjord
# Processing Record 44 of Set 2 | pochutla
# Processing Record 45 of Set 2 | senno
# Processing Record 46 of Set 2 | castro
# Processing Record 47 of Set 2 | albany
# Processing Record 48 of Set 2 | yumen
# Processing Record 49 of Set 2 | busselton
# Processing Record 50 of Set 2 | north platte
# Processing Record 1 of Set 3 | kaitangata
# Processing Record 2 of Set 3 | roma
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | ribeira grande
# Processing Record 5 of Set 3 | mattru
# Processing Record 6 of Set 3 | boa vista
# Processing Record 7 of Set 3 | vaini
# Processing Record 8 of Set 3 | saldanha
# Processing Record 9 of Set 3 | abha
# Processing Record 10 of Set 3 | rio gallegos
# Processing Record 11 of Set 3 | tomatlan
# Processing Record 12 of Set 3 | belmonte
# Processing Record 13 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 3 | celestun
# Processing Record 15 of Set 3 | jackson
# Processing Record 16 of Set 3 | madang
# Processing Record 17 of Set 3 | syracuse
# Processing Record 18 of Set 3 | lianran
# Processing Record 19 of Set 3 | ponta do sol
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | lillooet
# Processing Record 22 of Set 3 | cherskiy
# Processing Record 23 of Set 3 | luwero
# Processing Record 24 of Set 3 | belize
# Processing Record 25 of Set 3 | liwale
# Processing Record 26 of Set 3 | algiers
# Processing Record 27 of Set 3 | egvekinot
# Processing Record 28 of Set 3 | tungkang
# City not found. Skipping...
# Processing Record 29 of Set 3 | te anau
# Processing Record 30 of Set 3 | yazykovo
# Processing Record 31 of Set 3 | kanata
# Processing Record 32 of Set 3 | cidreira
# Processing Record 33 of Set 3 | bathsheba
# Processing Record 34 of Set 3 | arona
# Processing Record 35 of Set 3 | mataura
# Processing Record 36 of Set 3 | gulshat
# City not found. Skipping...
# Processing Record 37 of Set 3 | cayenne
# Processing Record 38 of Set 3 | lebu
# Processing Record 39 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 3 | taltal
# Processing Record 41 of Set 3 | pisco
# Processing Record 42 of Set 3 | mount pleasant
# Processing Record 43 of Set 3 | katsuura
# Processing Record 44 of Set 3 | khatanga
# Processing Record 45 of Set 3 | faanui
# Processing Record 46 of Set 3 | guerrero negro
# Processing Record 47 of Set 3 | jawa
# Processing Record 48 of Set 3 | avarua
# Processing Record 49 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 3 | sisimiut
# Processing Record 1 of Set 4 | sechura
# Processing Record 2 of Set 4 | bhuj
# Processing Record 3 of Set 4 | areosa
# Processing Record 4 of Set 4 | deputatskiy
# Processing Record 5 of Set 4 | ramhormoz
# Processing Record 6 of Set 4 | corrente
# Processing Record 7 of Set 4 | tolstoy-yurt
# Processing Record 8 of Set 4 | strezhevoy
# Processing Record 9 of Set 4 | hasaki
# Processing Record 10 of Set 4 | hyeres
# Processing Record 11 of Set 4 | vostok
# Processing Record 12 of Set 4 | torbay
# Processing Record 13 of Set 4 | arraial do cabo
# Processing Record 14 of Set 4 | sabang
# Processing Record 15 of Set 4 | kidal
# Processing Record 16 of Set 4 | victoria
# Processing Record 17 of Set 4 | san andres
# Processing Record 18 of Set 4 | jiujiang
# Processing Record 19 of Set 4 | templin
# Processing Record 20 of Set 4 | innisfail
# Processing Record 21 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 4 | yanchukan
# City not found. Skipping...
# Processing Record 23 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 4 | san ramon
# Processing Record 25 of Set 4 | tyssedal
# Processing Record 26 of Set 4 | abu dhabi
# Processing Record 27 of Set 4 | juifang
# City not found. Skipping...
# Processing Record 28 of Set 4 | zambezi
# Processing Record 29 of Set 4 | sola
# Processing Record 30 of Set 4 | tuatapere
# Processing Record 31 of Set 4 | kahului
# Processing Record 32 of Set 4 | namibe
# Processing Record 33 of Set 4 | valdez
# Processing Record 34 of Set 4 | zhigansk
# Processing Record 35 of Set 4 | olafsvik
# Processing Record 36 of Set 4 | sandakan
# Processing Record 37 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 4 | porgera
# Processing Record 39 of Set 4 | half moon bay
# Processing Record 40 of Set 4 | fort-shevchenko
# Processing Record 41 of Set 4 | dali
# Processing Record 42 of Set 4 | la huacana
# Processing Record 43 of Set 4 | tapes
# Processing Record 44 of Set 4 | tuktoyaktuk
# Processing Record 45 of Set 4 | nemuro
# Processing Record 46 of Set 4 | aklavik
# Processing Record 47 of Set 4 | kashi
# Processing Record 48 of Set 4 | ogaminana
# Processing Record 49 of Set 4 | idrinskoye
# Processing Record 50 of Set 4 | miguel hidalgo
# Processing Record 1 of Set 5 | mamu kanjan
# Processing Record 2 of Set 5 | araouane
# Processing Record 3 of Set 5 | high level
# Processing Record 4 of Set 5 | jalu
# Processing Record 5 of Set 5 | cockburn town
# Processing Record 6 of Set 5 | cerrito
# Processing Record 7 of Set 5 | pangkalanbuun
# Processing Record 8 of Set 5 | coquimbo
# Processing Record 9 of Set 5 | lagoa
# Processing Record 10 of Set 5 | norman wells
# Processing Record 11 of Set 5 | alofi
# Processing Record 12 of Set 5 | kutum
# Processing Record 13 of Set 5 | bansko
# Processing Record 14 of Set 5 | chuy
# Processing Record 15 of Set 5 | barrow
# Processing Record 16 of Set 5 | la ronge
# Processing Record 17 of Set 5 | antofagasta
# Processing Record 18 of Set 5 | shimanovsk
# Processing Record 19 of Set 5 | martapura
# Processing Record 20 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 5 | naruja
# Processing Record 22 of Set 5 | makakilo city
# Processing Record 23 of Set 5 | qandala
# Processing Record 24 of Set 5 | xining
# Processing Record 25 of Set 5 | nelson bay
# Processing Record 26 of Set 5 | furano
# Processing Record 27 of Set 5 | luderitz
# Processing Record 28 of Set 5 | nadvoitsy
# Processing Record 29 of Set 5 | naron
# Processing Record 30 of Set 5 | itarema
# Processing Record 31 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 5 | belluno
# Processing Record 33 of Set 5 | zhanatas
# City not found. Skipping...
# Processing Record 34 of Set 5 | sarakhs
# Processing Record 35 of Set 5 | tefe
# Processing Record 36 of Set 5 | chester
# Processing Record 37 of Set 5 | alice springs
# Processing Record 38 of Set 5 | merauke
# Processing Record 39 of Set 5 | mansa
# Processing Record 40 of Set 5 | berlevag
# Processing Record 41 of Set 5 | bethel
# Processing Record 42 of Set 5 | kapaa
# Processing Record 43 of Set 5 | gat
# Processing Record 44 of Set 5 | el balyana
# City not found. Skipping...
# Processing Record 45 of Set 5 | dongli
# Processing Record 46 of Set 5 | hami
# Processing Record 47 of Set 5 | mount isa
# Processing Record 48 of Set 5 | gornyak
# Processing Record 49 of Set 5 | gazojak
# Processing Record 50 of Set 5 | udachnyy
# Processing Record 1 of Set 6 | yashkul
# Processing Record 2 of Set 6 | aleksandriyskaya
# Processing Record 3 of Set 6 | medicine hat
# Processing Record 4 of Set 6 | hambantota
# Processing Record 5 of Set 6 | blagoyevo
# Processing Record 6 of Set 6 | pilar
# Processing Record 7 of Set 6 | buala
# Processing Record 8 of Set 6 | guanare
# Processing Record 9 of Set 6 | matadi
# Processing Record 10 of Set 6 | great yarmouth
# Processing Record 11 of Set 6 | belozerskoye
# Processing Record 12 of Set 6 | saint-augustin
# Processing Record 13 of Set 6 | codrington
# Processing Record 14 of Set 6 | padang
# Processing Record 15 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 16 of Set 6 | hofn
# Processing Record 17 of Set 6 | kamiiso
# Processing Record 18 of Set 6 | richards bay
# Processing Record 19 of Set 6 | barranca
# Processing Record 20 of Set 6 | ilulissat
# Processing Record 21 of Set 6 | comrat
# Processing Record 22 of Set 6 | pucallpa
# Processing Record 23 of Set 6 | kushima
# Processing Record 24 of Set 6 | arman
# Processing Record 25 of Set 6 | geresk
# City not found. Skipping...
# Processing Record 26 of Set 6 | tetouan
# Processing Record 27 of Set 6 | thurso
# Processing Record 28 of Set 6 | tsabong
# Processing Record 29 of Set 6 | silchar
# Processing Record 30 of Set 6 | klaksvik
# Processing Record 31 of Set 6 | kieta
# Processing Record 32 of Set 6 | constitucion
# Processing Record 33 of Set 6 | san patricio
# Processing Record 34 of Set 6 | yinchuan
# Processing Record 35 of Set 6 | harper
# Processing Record 36 of Set 6 | bubaque
# Processing Record 37 of Set 6 | nuevo progreso
# Processing Record 38 of Set 6 | sijunjung
# Processing Record 39 of Set 6 | mabaruma
# Processing Record 40 of Set 6 | togur
# Processing Record 41 of Set 6 | lufilufi
# Processing Record 42 of Set 6 | asau
# Processing Record 43 of Set 6 | hearst
# Processing Record 44 of Set 6 | matara
# Processing Record 45 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 46 of Set 6 | beyneu
# Processing Record 47 of Set 6 | ksenyevka
# City not found. Skipping...
# Processing Record 48 of Set 6 | damghan
# Processing Record 49 of Set 6 | nantucket
# Processing Record 50 of Set 6 | sitka
# Processing Record 1 of Set 7 | tura
# Processing Record 2 of Set 7 | moron
# Processing Record 3 of Set 7 | nago
# Processing Record 4 of Set 7 | denpasar
# Processing Record 5 of Set 7 | ambovombe
# Processing Record 6 of Set 7 | haines junction
# Processing Record 7 of Set 7 | vorotynets
# Processing Record 8 of Set 7 | dovers
# Processing Record 9 of Set 7 | victor harbor
# Processing Record 10 of Set 7 | lac-megantic
# Processing Record 11 of Set 7 | mehendiganj
# Processing Record 12 of Set 7 | roald
# Processing Record 13 of Set 7 | suluq
# Processing Record 14 of Set 7 | san pedro
# Processing Record 15 of Set 7 | verkhnevilyuysk
# Processing Record 16 of Set 7 | caluquembe
# Processing Record 17 of Set 7 | tessalit
# Processing Record 18 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 7 | grottammare
# Processing Record 20 of Set 7 | kavaratti
# Processing Record 21 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 22 of Set 7 | ahipara
# Processing Record 23 of Set 7 | visby
# Processing Record 24 of Set 7 | inirida
# Processing Record 25 of Set 7 | korla
# Processing Record 26 of Set 7 | laguna
# Processing Record 27 of Set 7 | kruisfontein
# Processing Record 28 of Set 7 | el alto
# Processing Record 29 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 30 of Set 7 | chistoye
# Processing Record 31 of Set 7 | honiara
# Processing Record 32 of Set 7 | verkhnyaya inta
# Processing Record 33 of Set 7 | lavrentiya
# Processing Record 34 of Set 7 | bourges
# Processing Record 35 of Set 7 | carnarvon
# Processing Record 36 of Set 7 | jalapa
# Processing Record 37 of Set 7 | samarai
# Processing Record 38 of Set 7 | ancud
# Processing Record 39 of Set 7 | phan thiet
# Processing Record 40 of Set 7 | wasilla
# Processing Record 41 of Set 7 | labuhan
# Processing Record 42 of Set 7 | shimonoseki
# Processing Record 43 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 44 of Set 7 | sturgis
# Processing Record 45 of Set 7 | paveh
# Processing Record 46 of Set 7 | byron bay
# Processing Record 47 of Set 7 | grand-lahou
# Processing Record 48 of Set 7 | alugan
# Processing Record 49 of Set 7 | saint-joseph
# Processing Record 50 of Set 7 | kerki
# City not found. Skipping...
# Processing Record 1 of Set 8 | artyom
# Processing Record 2 of Set 8 | carutapera
# Processing Record 3 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 4 of Set 8 | manjacaze
# Processing Record 5 of Set 8 | yuksekova
# Processing Record 6 of Set 8 | kapuskasing
# Processing Record 7 of Set 8 | rawson
# Processing Record 8 of Set 8 | sao filipe
# Processing Record 9 of Set 8 | ariquemes
# Processing Record 10 of Set 8 | stornoway
# Processing Record 11 of Set 8 | moosomin
# Processing Record 12 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 13 of Set 8 | nioro
# Processing Record 14 of Set 8 | beidao
# Processing Record 15 of Set 8 | sahuaripa
# Processing Record 16 of Set 8 | teplyk
# Processing Record 17 of Set 8 | yulara
# Processing Record 18 of Set 8 | sinnamary
# Processing Record 19 of Set 8 | adrar
# Processing Record 20 of Set 8 | villamontes
# Processing Record 21 of Set 8 | bayji
# Processing Record 22 of Set 8 | broken hill
# Processing Record 23 of Set 8 | skibbereen
# Processing Record 24 of Set 8 | bucerias
# Processing Record 25 of Set 8 | talnakh
# Processing Record 26 of Set 8 | la palma
# Processing Record 27 of Set 8 | geraldton
# Processing Record 28 of Set 8 | haverfordwest
# Processing Record 29 of Set 8 | cabo san lucas
# Processing Record 30 of Set 8 | chisec
# Processing Record 31 of Set 8 | jiuquan
# Processing Record 32 of Set 8 | constantine
# Processing Record 33 of Set 8 | miraflores
# Processing Record 34 of Set 8 | ust-kan
# Processing Record 35 of Set 8 | sibi
# Processing Record 36 of Set 8 | itaituba
# Processing Record 37 of Set 8 | sioux lookout
# Processing Record 38 of Set 8 | arrecife
# Processing Record 39 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 8 | tazovskiy
# Processing Record 41 of Set 8 | trairi
# Processing Record 42 of Set 8 | megion
# Processing Record 43 of Set 8 | bitung
# Processing Record 44 of Set 8 | waingapu
# Processing Record 45 of Set 8 | sao domingos
# Processing Record 46 of Set 8 | mount abu
# Processing Record 47 of Set 8 | sao goncalo do amarante
# Processing Record 48 of Set 8 | oxilithos
# Processing Record 49 of Set 8 | sorland
# Processing Record 50 of Set 8 | tianpeng
# Processing Record 1 of Set 9 | pyaozerskiy
# Processing Record 2 of Set 9 | mahibadhoo
# Processing Record 3 of Set 9 | kuala sungai baru
# Processing Record 4 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 5 of Set 9 | bardiyah
# Processing Record 6 of Set 9 | nara
# Processing Record 7 of Set 9 | canakkale
# Processing Record 8 of Set 9 | gitega
# Processing Record 9 of Set 9 | nam tha
# City not found. Skipping...
# Processing Record 10 of Set 9 | maneadero
# Processing Record 11 of Set 9 | seymchan
# Processing Record 12 of Set 9 | awash
# Processing Record 13 of Set 9 | safford
# Processing Record 14 of Set 9 | sao joao da barra
# Processing Record 15 of Set 9 | baykit
# Processing Record 16 of Set 9 | high rock
# Processing Record 17 of Set 9 | hualmay
# Processing Record 18 of Set 9 | barentu
# Processing Record 19 of Set 9 | puerto del rosario
# Processing Record 20 of Set 9 | tagusao
# Processing Record 21 of Set 9 | taoudenni
# Processing Record 22 of Set 9 | los llanos de aridane
# Processing Record 23 of Set 9 | aguimes
# Processing Record 24 of Set 9 | rigaud
# Processing Record 25 of Set 9 | akonolinga
# Processing Record 26 of Set 9 | walvis bay
# Processing Record 27 of Set 9 | halifax
# Processing Record 28 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 29 of Set 9 | ngunguru
# Processing Record 30 of Set 9 | andenes
# Processing Record 31 of Set 9 | flin flon
# Processing Record 32 of Set 9 | dujuma
# City not found. Skipping...
# Processing Record 33 of Set 9 | pompeu
# Processing Record 34 of Set 9 | gambiran
# Processing Record 35 of Set 9 | havoysund
# Processing Record 36 of Set 9 | fallon
# Processing Record 37 of Set 9 | hobyo
# Processing Record 38 of Set 9 | charters towers
# Processing Record 39 of Set 9 | ortona
# Processing Record 40 of Set 9 | pudozh
# Processing Record 41 of Set 9 | burnie
# Processing Record 42 of Set 9 | nikolskoye
# Processing Record 43 of Set 9 | chambas
# Processing Record 44 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 45 of Set 9 | atar
# Processing Record 46 of Set 9 | broome
# Processing Record 47 of Set 9 | sondrio
# Processing Record 48 of Set 9 | fare
# Processing Record 49 of Set 9 | sur
# Processing Record 50 of Set 9 | manzanillo
# Processing Record 1 of Set 10 | najran
# Processing Record 2 of Set 10 | aykhal
# Processing Record 3 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 10 | karoi
# Processing Record 5 of Set 10 | kudahuvadhoo
# Processing Record 6 of Set 10 | bontang
# Processing Record 7 of Set 10 | pietarsaari
# Processing Record 8 of Set 10 | teguldet
# Processing Record 9 of Set 10 | port hedland
# Processing Record 10 of Set 10 | alamosa
# Processing Record 11 of Set 10 | one hundred mile house
# City not found. Skipping...
# Processing Record 12 of Set 10 | narsaq
# Processing Record 13 of Set 10 | tsiroanomandidy
# Processing Record 14 of Set 10 | vestmannaeyjar
# Processing Record 15 of Set 10 | queimadas
# Processing Record 16 of Set 10 | senneterre
# Processing Record 17 of Set 10 | middle island
# Processing Record 18 of Set 10 | ghanzi
# Processing Record 19 of Set 10 | longyearbyen
# Processing Record 20 of Set 10 | georgetown
# Processing Record 21 of Set 10 | talara
# Processing Record 22 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 10 | chapais
# Processing Record 24 of Set 10 | muravlenko
# Processing Record 25 of Set 10 | meulaboh
# Processing Record 26 of Set 10 | farafangana
# Processing Record 27 of Set 10 | maarianhamina
# Processing Record 28 of Set 10 | saint-louis
# Processing Record 29 of Set 10 | tiznit
# Processing Record 30 of Set 10 | hokitika
# Processing Record 31 of Set 10 | rocha
# Processing Record 32 of Set 10 | hamilton
# Processing Record 33 of Set 10 | bilibino
# Processing Record 34 of Set 10 | otsuki
# Processing Record 35 of Set 10 | abu samrah
# Processing Record 36 of Set 10 | ko samui
# Processing Record 37 of Set 10 | yenangyaung
# Processing Record 38 of Set 10 | loding
# Processing Record 39 of Set 10 | anaco
# Processing Record 40 of Set 10 | leningradskiy
# Processing Record 41 of Set 10 | poum
# Processing Record 42 of Set 10 | porto santo
# Processing Record 43 of Set 10 | mehamn
# Processing Record 44 of Set 10 | ust-kuyga
# Processing Record 45 of Set 10 | avera
# Processing Record 46 of Set 10 | ust-ordynskiy
# Processing Record 47 of Set 10 | san cristobal
# Processing Record 48 of Set 10 | alekseyevka
# Processing Record 49 of Set 10 | kampene
# Processing Record 50 of Set 10 | ixtapa
# Processing Record 1 of Set 11 | ontario
# Processing Record 2 of Set 11 | necochea
# Processing Record 3 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 4 of Set 11 | menongue
# Processing Record 5 of Set 11 | san bartolome de tirajana
# Processing Record 6 of Set 11 | mangrol
# Processing Record 7 of Set 11 | bafq
# Processing Record 8 of Set 11 | zaraza
# Processing Record 9 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 10 of Set 11 | ponta delgada
# Processing Record 11 of Set 11 | east wenatchee bench
# Processing Record 12 of Set 11 | okha
# Processing Record 13 of Set 11 | bayonet point
# Processing Record 14 of Set 11 | xai-xai
# Processing Record 15 of Set 11 | carberry
# Processing Record 16 of Set 11 | kyren
# Processing Record 17 of Set 11 | jumla
# Processing Record 18 of Set 11 | suntar
# Processing Record 19 of Set 11 | casino
# Processing Record 20 of Set 11 | oga
# Processing Record 21 of Set 11 | azangaro
# Processing Record 22 of Set 11 | atkarsk
# Processing Record 23 of Set 11 | alipur
# Processing Record 24 of Set 11 | jishou
# Processing Record 25 of Set 11 | quatre cocos
# Processing Record 26 of Set 11 | gallup
# Processing Record 27 of Set 11 | san jose
# Processing Record 28 of Set 11 | beloha
# Processing Record 29 of Set 11 | viking
# Processing Record 30 of Set 11 | amahai
# Processing Record 31 of Set 11 | gamba
# Processing Record 32 of Set 11 | husavik
# Processing Record 33 of Set 11 | tucuman
# Processing Record 34 of Set 11 | aripuana
# Processing Record 35 of Set 11 | soe
# Processing Record 36 of Set 11 | college
# Processing Record 37 of Set 11 | maragogi
# Processing Record 38 of Set 11 | forecariah
# Processing Record 39 of Set 11 | chernyshevskiy
# Processing Record 40 of Set 11 | turan
# Processing Record 41 of Set 11 | svetlogorsk
# Processing Record 42 of Set 11 | harbour breton
# Processing Record 43 of Set 11 | ibia
# Processing Record 44 of Set 11 | thunder bay
# Processing Record 45 of Set 11 | santa ines
# Processing Record 46 of Set 11 | tra vinh
# Processing Record 47 of Set 11 | talcahuano
# Processing Record 48 of Set 11 | vila franca do campo
# Processing Record 49 of Set 11 | kavieng
# Processing Record 50 of Set 11 | puerto colombia
# Processing Record 1 of Set 12 | voh
# Processing Record 2 of Set 12 | karpogory
# Processing Record 3 of Set 12 | nuuk
# Processing Record 4 of Set 12 | paragominas
# Processing Record 5 of Set 12 | naryan-mar
# Processing Record 6 of Set 12 | faya
# Processing Record 7 of Set 12 | lewistown
# Processing Record 8 of Set 12 | ankang
# Processing Record 9 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 12 | beringovskiy
# Processing Record 11 of Set 12 | shingu
# Processing Record 12 of Set 12 | puerto escondido
# Processing Record 13 of Set 12 | gewane
# Processing Record 14 of Set 12 | winslow
# Processing Record 15 of Set 12 | dumai
# Processing Record 16 of Set 12 | kamenka
# Processing Record 17 of Set 12 | bambous virieux
# Processing Record 18 of Set 12 | neyshabur
# Processing Record 19 of Set 12 | metro
# Processing Record 20 of Set 12 | san vicente
# Processing Record 21 of Set 12 | tilichiki
# Processing Record 22 of Set 12 | bonoua
# Processing Record 23 of Set 12 | nouakchott
# Processing Record 24 of Set 12 | birjand
# Processing Record 25 of Set 12 | portland
# Processing Record 26 of Set 12 | kaeo
# Processing Record 27 of Set 12 | montana
# Processing Record 28 of Set 12 | ahumada
# City not found. Skipping...
# Processing Record 29 of Set 12 | nanortalik
# Processing Record 30 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 12 | show low
# Processing Record 32 of Set 12 | kabompo
# Processing Record 33 of Set 12 | wuzhou
# Processing Record 34 of Set 12 | ugoofaaru
# Processing Record 35 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 12 | minsk
# Processing Record 37 of Set 12 | japura
# Processing Record 38 of Set 12 | obluche
# City not found. Skipping...
# Processing Record 39 of Set 12 | ketchikan
# Processing Record 40 of Set 12 | powell river
# Processing Record 41 of Set 12 | jatai
# Processing Record 42 of Set 12 | shuangyang
# Processing Record 43 of Set 12 | pakxan
# Processing Record 44 of Set 12 | west wendover
# Processing Record 45 of Set 12 | samana
# Processing Record 46 of Set 12 | lompoc
# Processing Record 47 of Set 12 | vytegra
# Processing Record 48 of Set 12 | ercis
# Processing Record 49 of Set 12 | bereda
# Processing Record 50 of Set 12 | sabya
# Processing Record 1 of Set 13 | henties bay
# Processing Record 2 of Set 13 | nizhniy odes
# Processing Record 3 of Set 13 | caceres
# Processing Record 4 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 13 | takoradi
# Processing Record 6 of Set 13 | batagay-alyta
# Processing Record 7 of Set 13 | dandong
# Processing Record 8 of Set 13 | pavelets
# Processing Record 9 of Set 13 | timmins
# Processing Record 10 of Set 13 | bonavista
# Processing Record 11 of Set 13 | jibuti
# Processing Record 12 of Set 13 | pak phanang
# Processing Record 13 of Set 13 | lata
# Processing Record 14 of Set 13 | busing
# Processing Record 15 of Set 13 | labrea
# Processing Record 16 of Set 13 | ahuimanu
# Processing Record 17 of Set 13 | wladyslawowo
# Processing Record 18 of Set 13 | touros
# Processing Record 19 of Set 13 | hudson bay
# Processing Record 20 of Set 13 | bababe
# City not found. Skipping...
# Processing Record 21 of Set 13 | walcz
# Processing Record 22 of Set 13 | ntcheu
# Processing Record 23 of Set 13 | birao
# Processing Record 24 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 13 | dubenskiy
# City not found. Skipping...
# Processing Record 26 of Set 13 | karlskoga
# Processing Record 27 of Set 13 | kenai
# Processing Record 28 of Set 13 | meiktila
# Processing Record 29 of Set 13 | songling
# Processing Record 30 of Set 13 | coos bay
# Processing Record 31 of Set 13 | bhagalpur
# Processing Record 32 of Set 13 | soller
# Processing Record 33 of Set 13 | wanxian
# Processing Record 34 of Set 13 | chihuahua
# Processing Record 35 of Set 13 | zhangjiakou
# Processing Record 36 of Set 13 | pandamatenga
# Processing Record 37 of Set 13 | amapa
# Processing Record 38 of Set 13 | vanavara
# Processing Record 39 of Set 13 | soyo
# Processing Record 40 of Set 13 | cepelare
# Processing Record 41 of Set 13 | pingzhuang
# Processing Record 42 of Set 13 | nome
# Processing Record 43 of Set 13 | oranjemund
# Processing Record 44 of Set 13 | pokhara
# Processing Record 45 of Set 13 | inyonga
# Processing Record 46 of Set 13 | hirara
# Processing Record 47 of Set 13 | nhamunda
# Processing Record 48 of Set 13 | liku
# Processing Record 49 of Set 13 | khvatovka
# Processing Record 50 of Set 13 | eureka
# Processing Record 1 of Set 14 | huambo
# Processing Record 2 of Set 14 | masyaf
# Processing Record 3 of Set 14 | tautira
# Processing Record 4 of Set 14 | freeport
# Processing Record 5 of Set 14 | mana
# Processing Record 6 of Set 14 | santa rosa
# Processing Record 7 of Set 14 | ndouci
# City not found. Skipping...
# Processing Record 8 of Set 14 | hay river
# Processing Record 9 of Set 14 | kalmunai
# Processing Record 10 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 11 of Set 14 | mehrabpur
# Processing Record 12 of Set 14 | tairua
# Processing Record 13 of Set 14 | saint-pierre
# Processing Record 14 of Set 14 | ananindeua
# Processing Record 15 of Set 14 | the valley
# Processing Record 16 of Set 14 | hervey bay
# Processing Record 17 of Set 14 | waw
# Processing Record 18 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 14 | dingle
# Processing Record 20 of Set 14 | yacuiba
# Processing Record 21 of Set 14 | orange cove
# Processing Record 22 of Set 14 | ulaangom
# Processing Record 23 of Set 14 | gasan
# Processing Record 24 of Set 14 | price
# Processing Record 25 of Set 14 | qaqortoq
# Processing Record 26 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 27 of Set 14 | anadyr
# Processing Record 28 of Set 14 | dudinka
# Processing Record 29 of Set 14 | campinas
# Processing Record 30 of Set 14 | pimentel
# Processing Record 31 of Set 14 | rahuri
# Processing Record 32 of Set 14 | dunedin
# Processing Record 33 of Set 14 | turukhansk
# Processing Record 34 of Set 14 | xiongzhou
# Processing Record 35 of Set 14 | bandarbeyla
# Processing Record 36 of Set 14 | dvinskoy
# Processing Record 37 of Set 14 | tabas
# Processing Record 38 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 39 of Set 14 | charlestown
# Processing Record 40 of Set 14 | aquitania
# Processing Record 41 of Set 14 | neiafu
# Processing Record 42 of Set 14 | guarapari
# Processing Record 43 of Set 14 | jablanica
# Processing Record 44 of Set 14 | kirkwall
# Processing Record 45 of Set 14 | viedma
# Processing Record 46 of Set 14 | terme
# Processing Record 47 of Set 14 | ostrovnoy
# Processing Record 48 of Set 14 | fairbanks
# Processing Record 49 of Set 14 | machico
# Processing Record 50 of Set 14 | lindi
# Processing Record 1 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 2 of Set 15 | jiangyou
# Processing Record 3 of Set 15 | baruun-urt
# Processing Record 4 of Set 15 | moerai
# Processing Record 5 of Set 15 | latung
# Processing Record 6 of Set 15 | mecca
# Processing Record 7 of Set 15 | bad iburg
# Processing Record 8 of Set 15 | khovu-aksy
# Processing Record 9 of Set 15 | san rafael
# Processing Record 10 of Set 15 | kangaatsiaq
# Processing Record 11 of Set 15 | palimbang
# Processing Record 12 of Set 15 | acapulco
# Processing Record 13 of Set 15 | kargat
# Processing Record 14 of Set 15 | teahupoo
# Processing Record 15 of Set 15 | upata
# Processing Record 16 of Set 15 | westport
# Processing Record 17 of Set 15 | khani
# Processing Record 18 of Set 15 | guajara-mirim
# City not found. Skipping...
# Processing Record 19 of Set 15 | helong
# Processing Record 20 of Set 15 | sinegorye
# Processing Record 21 of Set 15 | saint anthony
# Processing Record 22 of Set 15 | caconda
# Processing Record 23 of Set 15 | santa cruz
# Processing Record 24 of Set 15 | requena
# Processing Record 25 of Set 15 | nalut
# Processing Record 26 of Set 15 | kyzyl-suu
# Processing Record 27 of Set 15 | kuusankoski
# Processing Record 28 of Set 15 | goderich
# Processing Record 29 of Set 15 | indramayu
# Processing Record 30 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 15 | santa maria da boa vista
# Processing Record 32 of Set 15 | rakiv lis
# Processing Record 33 of Set 15 | seddon
# Processing Record 34 of Set 15 | komsomolskiy
# Processing Record 35 of Set 15 | riyadh
# Processing Record 36 of Set 15 | palmas
# Processing Record 37 of Set 15 | emba
# Processing Record 38 of Set 15 | vrangel
# Processing Record 39 of Set 15 | pueblo
# Processing Record 40 of Set 15 | opobo
# City not found. Skipping...
# Processing Record 41 of Set 15 | khash
# Processing Record 42 of Set 15 | lodja
# Processing Record 43 of Set 15 | luganville
# Processing Record 44 of Set 15 | kloulklubed
# Processing Record 45 of Set 15 | baiyin
# Processing Record 46 of Set 15 | taburi
# City not found. Skipping...
# Processing Record 47 of Set 15 | umarkot
# Processing Record 48 of Set 15 | sychevka
# Processing Record 49 of Set 15 | butiama
# Processing Record 50 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 1 of Set 16 | karratha
# Processing Record 2 of Set 16 | rio grande
# Processing Record 3 of Set 16 | yokadouma
# Processing Record 4 of Set 16 | mayumba
# Processing Record 5 of Set 16 | yaan
# Processing Record 6 of Set 16 | tadine
# Processing Record 7 of Set 16 | tanete
# Processing Record 8 of Set 16 | sumbe
# Processing Record 9 of Set 16 | luangwa
# Processing Record 10 of Set 16 | arcoverde
# Processing Record 11 of Set 16 | camacha
# Processing Record 12 of Set 16 | totma
# Processing Record 13 of Set 16 | union hidalgo
# Processing Record 14 of Set 16 | yantal
# Processing Record 15 of Set 16 | eucaliptus
# Processing Record 16 of Set 16 | vinh
# Processing Record 17 of Set 16 | superior
# Processing Record 18 of Set 16 | kuching
# Processing Record 19 of Set 16 | aldan
# Processing Record 20 of Set 16 | beira
# Processing Record 21 of Set 16 | kettering
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Hilo      US  19.7297 -155.0900     78.53        78         100
# 1       Mahebourg      MU -20.4081   57.7000     76.24       100          75
# 2         Isangel      VU -19.5500  169.2667     83.46        78         100
# 3         Ushuaia      AR -54.8000  -68.3000     38.86        81          20
# 4             Hun      LY  29.1268   15.9477     70.16        16           2
# 5  Severo-Kurilsk      RU  50.6789  156.1250     30.02        70         100
# 6       Hithadhoo      MV  -0.6000   73.0833     83.19        70           8
# 7         Ligayan      PH   4.6533  119.4706     79.39        84         100
# 8            Gizo      SB  -8.1030  156.8419     84.09        71          78
# 9            Paro      BT  27.4305   89.4133     54.32        90          99
#
#    Wind Speed          Current Description
# 0       13.80              overcast clouds
# 1       17.27  light intensity shower rain
# 2        6.67              overcast clouds
# 3        9.22                   few clouds
# 4       13.91                    clear sky
# 5       27.13              overcast clouds
# 6        6.78                    clear sky
# 7       17.60              overcast clouds
# 8        8.08                broken clouds
# 9        2.33              overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
